# %% [markdown]
# # STORY

# %% [markdown]
#  Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings on dharma, bravery, and justice. From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains. He grew up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates were vying for control, often oppressing the local population, which deeply disturbed him and fueled his desire to establish Swarajya, or self-rule for the Marathas. By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy. As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India. In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan. Shivaji’s raids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolstered his legend. He realized that a powerful navy was crucial to safeguard his territories from foreign invasions, leading him to develop one of the earliest organized naval forces in India, allowing him to secure coastal areas against Portuguese, British, and Siddis forces. In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos. Shivaji’s administrative system was highly efficient, and he emphasized the welfare of his people, setting up systems to reduce corruption and create a fair tax structure; his Ashta Pradhan (Council of Eight Ministers) included departments for finance, internal affairs, foreign policy, and military to ensure smooth governance. Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites. His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time. Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legendary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses. As his fame grew, the Maratha Empire began to influence regions far beyond Maharashtra, with Maratha forces eventually becoming a significant power across India. Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death. His life and ideals—valor, respect for all faiths, and self-rule—continue to inspire millions, and his legacy endures in the form of the Maratha Empire’s contributions to India’s history and culture.

# %% [markdown]
# # Questions Using SpaCy, NLTK, and TextBlob
#
#
# 1- Tokenization
#
# Use NLTK to tokenize the text into words.
#
#
# Tokenize the text into sentences using spaCy.
#
#
# 2- Named Entity Recognition (NER)
#
# Use spaCy to extract all named entities in the text.
#
#
# Identify and count all locations mentioned in the text using spaCy's NER.
#
#
# 3- Part of Speech (POS) Tagging
#
# Use TextBlob to tag the parts of speech for each word.
#
# Extract and list all nouns in the text using spaCy.
#
#
# 4- Stop Words Removal
#
# Use NLTK to remove stop words from the text and display the cleaned text.
#
#
# Use spaCy to remove stop words, then join and display the text without stop words.
#
#
# 5- Lemmatization
#
# Use spaCy to lemmatize each word in the text.
#
#
# Use NLTK to lemmatize only the verbs in the text.
#
# 6- Sentiment Analysis
#
# Use TextBlob to perform sentiment analysis on the entire text.
#
#
# Divide the text into sentences and analyze the sentiment of each sentence with TextBlob.
#
#
# 7- N-Grams
#
# Generate bigrams (two-word combinations) using NLTK.
#
#
# Generate trigrams (three-word combinations) using TextBlob.
#
#
# 8- Frequency Distribution
#
# Use NLTK to compute the frequency distribution of words in the text.
#
# Find the 5 most common nouns in the text using spaCy.
#
#
# 9- Dependency Parsing
#
# Extract and display dependency parse information for each sentence using spaCy.
#
# Visualize the dependency tree of the first sentence using spaCy’s displacy tool.
#
#
# 10- Phrase Matching
#
# Identify occurrences of the phrase "Maratha Empire" using spaCy's PhraseMatcher.
#
#
# Use spaCy’s Matcher to find patterns where Shivaji Maharaj is mentioned along with actions (verbs).
#
#
# 11- Sentence Similarity
#
#
# Calculate the similarity between the first two sentences of the text using spaCy.
#
#
# Use TextBlob to compute the similarity between sentences mentioning "Shivaji" and "Mughal Empire."
#
#
# 12- Translation
#
#
# Translate the first paragraph into Hindi using TextBlob.
#
#
# Translate the phrase "Hindavi Swarajya" into French using TextBlob.
#
#
# 13- Keyword Extraction
#
#
# Extract keywords using NLTK’s frequency distribution (common nouns and verbs).
#
#
# Use spaCy to identify and list unique keywords from the text (filter out stop words).
#
#
# 14- Coreference Resolution
#
#
#
# Use spaCy's neuralcoref extension to resolve pronouns in the text.
#
#
# Identify any instances where pronouns can be replaced with entity names for better clarity.
#
#
# 15- Sentiment Polarity Distribution
#
# Calculate and plot the sentiment polarity distribution for each sentence in the text using TextBlob.
#
#
# Identify and display the most positive and most negative sentences based on sentiment scores.
#
#
# 16- Extract Dates and Events
#
#
# Identify all dates mentioned in the text using spaCy.
#
# Use regex to find sentences related to events happening in specific years (e.g., 1674 or 1680).
#
#
# 17- Synonyms and Antonyms
#
# Use TextBlob's WordNet to find synonyms for "bravery," "justice," and "valor."
#
#
# Find antonyms of "oppression" and "invasion" using NLTK’s WordNet.
#
#
# 18- Spelling Correction
#
# Introduce 5 spelling errors in the text and use TextBlob to correct them.
#
#
# Identify words with potential spelling errors using TextBlob.
#
#
# 19- Extract Subject-Verb-Object Triples
#
# Use spaCy to extract subject-verb-object triples from the sentences.
#
#
# Identify and list sentences where "Shivaji" is the subject and a verb follows, using dependency parsing.
#
# 20- Create a Summary
#
# Summarize the text using TextBlob by extracting key sentences.
#
#
# Generate a summary using NLTK’s summarize function on cleaned text.

# %% [markdown]
# #1- Tokenization
#
# Use NLTK to tokenize the text into words.

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# !pip install sumy
# Out:
# Requirement already satisfied: sumy in /usr/local/lib/python3.10/dist-packages (0.11.0)
# Requirement already satisfied: docopt<0.7,>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from sumy) (0.6.2)
# Requirement already satisfied: breadability>=0.1.20 in /usr/local/lib/python3.10/dist-packages (from sumy) (0.1.20)
# Requirement already satisfied: requests>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from sumy) (2.32.3)
# Requirement already satisfied: pycountry>=18.2.23 in /usr/local/lib/python3.10/dist-packages (from sumy) (24.6.1)
# Requirement already satisfied: nltk>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from sumy) (3.8.1)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from breadability>=0.1.20->sumy) (5.2.0)
# Requirement already satisfied: lxml>=2.0 in /usr/local/lib/python3.10/dist-packages (from breadability>=0.1.20->sumy) (4.9.4)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.0.2->sumy) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.0.2->sumy) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.0.2->sumy) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.0.2->sumy) (4.66.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.7.0->sumy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.7.0->sumy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.7.0->sumy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.7.0->sumy) (2024.8.30)

# %%
text = "Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings on dharma, bravery, and justice. From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains. He grew up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates were vying for control, often oppressing the local population, which deeply disturbed him and fueled his desire to establish Swarajya, or self-rule for the Marathas. By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy. As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India. In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan. Shivaji’s raids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolstered his legend. He realized that a powerful navy was crucial to safeguard his territories from foreign invasions, leading him to develop one of the earliest organized naval forces in India, allowing him to secure coastal areas against Portuguese, British, and Siddis forces. In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos. Shivaji’s administrative system was highly efficient, and he emphasized the welfare of his people, setting up systems to reduce corruption and create a fair tax structure; his Ashta Pradhan (Council of Eight Ministers) included departments for finance, internal affairs, foreign policy, and military to ensure smooth governance. Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites. His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time. Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legendary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses. As his fame grew, the Maratha Empire began to influence regions far beyond Maharashtra, with Maratha forces eventually becoming a significant power across India. Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death. His life and ideals—valor, respect for all faiths, and self-rule—continue to inspire millions, and his legacy endures in the form of the Maratha Empire’s contributions to India’s history and culture."

# %%
word = word_tokenize(text)
word
# Out:
# ['Chhatrapati',
#  'Shivaji',
#  'Maharaj',
#  'was',
#  'born',
#  'on',
#  'February',
#  '19',
#  ',',
#  '1630',
#  ',',
#  'at',
#  'Shivneri',
#  'Fort',
#  'in',
#  'Maharashtra',
#  ',',
#  'to',
#  'Shahaji',
#  'Bhonsle',
#  ',',
#  'a',
#  'Maratha',
#  'general',
#  ',',
#  'and',
#  'Jijabai',
#  ',',
#  'who',
#  'deeply',
#  'influenced',
#  'Shivaji',
#  'with',
#  'her',
#  'teachings',
#  'on',
#  'dharma',
#  ',',
#  'bravery',
#  ',',
#  'and',
#  'justice',
#  '.',
#  'From',
#  'an',
#  'early',
#  'age',
#  ',',
#  'Shivaji',
#  'exhibited',
#  'remarkable',
#  'leadership',
#  'qualities',
#  ',',
#  'forming',
#  'a',
#  'group',
#  'of',
#  'loyal',
#  'followers',
#  'and',
#  'honing',
#  'his',
#  'military',
#  'skills',
#  'in',
#  'the',
#  'rugged',
#  'terrain',
#  'of',
#  'the',
#  'Sahyadri',
#  'mountains',
#  '.',
#  'He',
#  'grew',
#  'up',
#  'during',
#  'a',
#  'time',
#  'when',
#  'the',
#  'Mughal',
#  'Empire',
#  'under',
#  'Emperor',
#  'Aurangzeb',
#  'and',
#  'the',
#  'Deccan',
#  'Sultanates',
#  'were',
#  'vying',
#  'for',
#  'control',
#  ',',
#  'often',
#  'oppressing',
#  'the',
#  'local',
#  'population',
#  ',',
#  'which',
#  'deeply',
#  'disturbed',
#  'him',
#  'and',
#  'fueled',
#  'his',
#  'desire',
#  'to',
#  'establish',
#  'Swarajya',
#  ',',
#  'or',
#  'self-rule',
#  'for',
#  'the',
#  'Marathas',
#  '.',
#  'By',
#  'the',
#  'age',
#  'of',
#  '16',
#  ',',
#  'Shivaji',
#  'had',
#  'captured',
#  'his',
#  'first',
#  'fort',
#  ',',
#  'Torna',
#  ',',
#  'using',
#  'guerrilla',
#  'warfare',
#  'tactics',
#  'that',
#  'would',
#  'later',
#  'become',
#  'a',
#  'hallmark',
#  'of',
#  'his',
#  'military',
#  'strategy',
#  '.',
#  'As',
#  'his',
#  'conquests',
#  'grew',
#  ',',
#  'he',
#  'formed',
#  'alliances',
#  'with',
#  'local',
#  'leaders',
#  ',',
#  'securing',
#  'key',
#  'forts',
#  'like',
#  'Raigad',
#  ',',
#  'Kondana',
#  ',',
#  'and',
#  'Purandar',
#  ',',
#  'establishing',
#  'a',
#  'solid',
#  'territorial',
#  'base',
#  'in',
#  'western',
#  'India',
#  '.',
#  'In',
#  '1659',
#  ',',
#  'he',
#  'faced',
#  'and',
#  'defeated',
#  'Afzal',
#  'Khan',
#  ',',
#  'a',
#  'prominent',
#  'general',
#  'of',
#  'the',
#  'Bijapur',
#  'Sultanate',
#  ',',
#  'solidifying',
#  'his',
#  'reputation',
#  'as',
#  'a',
#  'brave',
#  'and',
#  'tactical',
#  'leader',
#  ';',
#  'this',
#  'victory',
#  'was',
#  'crucial',
#  'in',
#  'establishing',
#  'his',
#  'control',
#  'over',
#  'much',
#  'of',
#  'the',
#  'Deccan',
#  '.',
#  'Shivaji',
#  '’',
#  's',
#  'raids',
#  'on',
#  'Mughal',
#  'territories',
#  'and',
#  'his',
#  'escape',
#  'from',
#  'the',
#  'clutches',
#  'of',
#  'Aurangzeb',
#  'in',
#  'Agra',
#  'in',
#  '1666',
#  'further',
#  'bolstered',
#  'his',
#  'legend',
#  '.',
#  'He',
#  'realized',
#  'that',
#  'a',
#  'powerful',
#  'navy',
#  'was',
#  'crucial',
#  'to',
#  'safeguard',
#  'his',
#  'territories',
#  'from',
#  'foreign',
#  'invasions',
#  ',',
#  'leading',
#  'him',
#  'to',
#  'develop',
#  'one',
#  'of',
#  'the',
#  'earliest',
#  'organized',
#  'naval',
#  'forces',
#  'in',
#  'India',
#  ',',
#  'allowing',
#  'him',
#  'to',
#  'secure',
#  'coastal',
#  'areas',
#  'against',
#  'Portuguese',
#  ',',
#  'British',
#  ',',
#  'and',
#  'Siddis',
#  'forces',
#  '.',
#  'In',
#  '1674',
#  ',',
#  'he',
#  'formally',
#  'crowned',
#  'himself',
#  'as',
#  'Chhatrapati',
#  'at',
#  'Raigad',
#  'Fort',
#  ',',
#  'declaring',
#  'his',
#  'independence',
#  'and',
#  'establishing',
#  'the',
#  'Maratha',
#  'Empire',
#  ',',
#  'thus',
#  'becoming',
#  'the',
#  'first',
#  'king',
#  'to',
#  'establish',
#  'Hindavi',
#  'Swarajya',
#  ',',
#  'an',
#  'autonomous',
#  'kingdom',
#  'with',
#  'a',
#  'structured',
#  'administrative',
#  'framework',
#  'rooted',
#  'in',
#  'Indian',
#  'ethos',
#  '.',
#  'Shivaji',
#  '’',
#  's',
#  'administrative',
#  'system',
#  'was',
#  'highly',
#  'efficient',
#  ',',
#  'and',
#  'he',
#  'emphasized',
#  'the',
#  'welfare',
#  'of',
#  'his',
#  'people',
#  ',',
#  'setting',
#  'up',
#  'systems',
#  'to',
#  'reduce',
#  'corruption',
#  'and',
#  'create',
#  'a',
#  'fair',
#  'tax',
#  'structure',
#  ';',
#  'his',
#  'Ashta',
#  'Pradhan',
#  '(',
#  'Council',
#  'of',
#  'Eight',
#  'Ministers',
#  ')',
#  'included',
#  'departments',
#  'for',
#  'finance',
#  ',',
#  'internal',
#  'affairs',
#  ',',
#  'foreign',
#  'policy',
#  ',',
#  'and',
#  'military',
#  'to',
#  'ensure',
#  'smooth',
#  'governance',
#  '.',
#  'Shivaji',
#  'showed',
#  'a',
#  'progressive',
#  'approach',
#  'towards',
#  'governance',
#  ',',
#  'promoting',
#  'religious',
#  'tolerance',
#  'and',
#  'respecting',
#  'the',
#  'diversity',
#  'within',
#  'his',
#  'empire',
#  ',',
#  'even',
#  'appointing',
#  'Muslims',
#  'to',
#  'key',
#  'positions',
#  'in',
#  'his',
#  'administration',
#  'and',
#  'banning',
#  'the',
#  'harassment',
#  'of',
#  'women',
#  'and',
#  'looting',
#  'of',
#  'religious',
#  'sites',
#  '.',
#  'His',
#  'respect',
#  'for',
#  'women',
#  'and',
#  'his',
#  'advocacy',
#  'for',
#  'justice',
#  'inspired',
#  'trust',
#  'and',
#  'loyalty',
#  'among',
#  'his',
#  'people',
#  ',',
#  'making',
#  'him',
#  'an',
#  'ideal',
#  'ruler',
#  'for',
#  'his',
#  'time',
#  '.',
#  'Shivaji',
#  'Maharaj',
#  '’',
#  's',
#  'guerrilla',
#  'tactics',
#  ',',
#  'known',
#  'as',
#  '“',
#  'Ganimi',
#  'Kava',
#  ',',
#  '”',
#  'became',
#  'legendary',
#  'and',
#  'enabled',
#  'him',
#  'to',
#  'outmaneuver',
#  'much',
#  'larger',
#  'and',
#  'better-equipped',
#  'armies',
#  'repeatedly',
#  ',',
#  'allowing',
#  'him',
#  'to',
#  'expand',
#  'his',
#  'empire',
#  'while',
#  'minimizing',
#  'losses',
#  '.',
#  'As',
#  'his',
#  'fame',
#  'grew',
#  ',',
#  'the',
#  'Maratha',
#  'Empire',
#  'began',
#  'to',
#  'influence',
#  'regions',
#  'far',
#  'beyond',
#  'Maharashtra',
#  ',',
#  'with',
#  'Maratha',
#  'forces',
#  'eventually',
#  'becoming',
#  'a',
#  'significant',
#  'power',
#  'across',
#  'India',
#  '.',
#  'Shivaji',
#  'passed',
#  'away',
#  'on',
#  'April',
#  '3',
#  ',',
#  '1680',
#  ',',
#  'at',
#  'Raigad',
#  'Fort',
#  ',',
#  'leaving',
#  'behind',
#  'a',
#  'powerful',
#  'legacy',
#  'and',
#  'a',
#  'well-organized',
#  'state',
#  'that',
#  'continued',
#  'to',
#  'expand',
#  'after',
#  'his',
#  'death',
#  '.',
#  'His',
#  'life',
#  'and',
#  'ideals—valor',
#  ',',
#  'respect',
#  'for',
#  'all',
#  'faiths',
#  ',',
#  'and',
#  'self-rule—continue',
#  'to',
#  'inspire',
#  'millions',
#  ',',
#  'and',
#  'his',
#  'legacy',
#  'endures',
#  'in',
#  'the',
#  'form',
#  'of',
#  'the',
#  'Maratha',
#  'Empire',
#  '’',
#  's',
#  'contributions',
#  'to',
#  'India',
#  '’',
#  's',
#  'history',
#  'and',
#  'culture',
#  '.']

# %%
#Tokenize the text into sentences using spaCy
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp(text)
sentences = [sent.text for sent in doc.sents]
print(sentences)
# Out:
# ['Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings on dharma, bravery, and justice.', 'From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains.', 'He grew up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates were vying for control, often oppressing the local population, which deeply disturbed him and fueled his desire to establish Swarajya, or self-rule for the Marathas.', 'By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy.', 'As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India.', 'In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan.', 'Shivaji’s raids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolstered his legend.', 'He realized that a powerful navy was crucial to safeguard his territories from foreign invasions, leading him to develop one of the earliest organized naval forces in India, allowing him to secure coastal areas against Portuguese, British, and Siddis forces.', 'In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos.', 'Shivaji’s administrative system was highly efficient, and he emphasized the welfare of his people, setting up systems to reduce corruption and create a fair tax structure; his Ashta Pradhan (Council of Eight Ministers) included departments for finance, internal affairs, foreign policy, and military to ensure smooth governance.', 'Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites.', 'His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time.', 'Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legendary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses.', 'As his fame grew, the Maratha Empire began to influence regions far beyond Maharashtra, with Maratha forces eventually becoming a significant power across India.', 'Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death.', 'His life and ideals—valor, respect for all faiths, and self-rule—continue to inspire millions, and his legacy endures in the form of the Maratha Empire’s contributions to India’s history and culture.']

# %% [markdown]
# #2. Named Entity Recognition (NER)
# Extract Named Entities using SpaCy

# %%
entities = [(ent.text, ent.label_) for ent in doc.ents]
print(entities)
# Out:
# [('Chhatrapati Shivaji Maharaj', 'PERSON'), ('February 19, 1630', 'DATE'), ('Shivneri Fort', 'FAC'), ('Maharashtra', 'GPE'), ('Shahaji Bhonsle', 'ORG'), ('Maratha', 'GPE'), ('Jijabai', 'GPE'), ('Shivaji', 'PERSON'), ('Shivaji', 'PERSON'), ('Sahyadri', 'LOC'), ('Swarajya', 'ORG'), ('Marathas', 'PERSON'), ('the age of 16', 'DATE'), ('Shivaji', 'PERSON'), ('first', 'ORDINAL'), ('Torna', 'GPE'), ('Raigad', 'GPE'), ('Kondana', 'PERSON'), ('Purandar', 'ORG'), ('India', 'GPE'), ('1659', 'DATE'), ('Afzal Khan', 'PERSON'), ('the Bijapur Sultanate', 'GPE'), ('Deccan', 'PRODUCT'), ('Shivaji', 'PERSON'), ('Agra', 'ORG'), ('1666', 'DATE'), ('India', 'GPE'), ('Portuguese', 'NORP'), ('British', 'NORP'), ('Siddis', 'NORP'), ('1674', 'DATE'), ('Raigad Fort', 'FAC'), ('the Maratha Empire', 'LOC'), ('first', 'ORDINAL'), ('Hindavi Swarajya', 'PERSON'), ('Indian', 'NORP'), ('Shivaji', 'PERSON'), ('Ashta Pradhan (Council of Eight Ministers', 'ORG'), ('Shivaji', 'PERSON'), ('Muslims', 'NORP'), ('Shivaji Maharaj', 'PERSON'), ('Ganimi Kava', 'PERSON'), ('the Maratha Empire', 'ORG'), ('Maharashtra', 'ORG'), ('Maratha', 'PERSON'), ('India', 'GPE'), ('April 3, 1680', 'DATE'), ('Raigad Fort', 'FAC'), ('millions', 'CARDINAL'), ('the Maratha Empire’s', 'LOC'), ('India', 'GPE')]

# %%
#Count Locations:
locations = [ent.text for ent in doc.ents if ent.label_ == "GPE"]
location_count = len(locations)
print("Location Count:", location_count)
print(locations)
# Out:
# Location Count: 10
# ['Maharashtra', 'Maratha', 'Jijabai', 'Torna', 'Raigad', 'India', 'the Bijapur Sultanate', 'India', 'India', 'India']

# %% [markdown]
# #3. Part of Speech (POS) Tagging
# TextBlob POS Tagging:

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
from textblob import TextBlob

blob = TextBlob(text)
pos_tags = blob.tags
pos_tags
# Out:
# [('Chhatrapati', 'NNP'),
#  ('Shivaji', 'NNP'),
#  ('Maharaj', 'NNP'),
#  ('was', 'VBD'),
#  ('born', 'VBN'),
#  ('on', 'IN'),
#  ('February', 'NNP'),
#  ('19', 'CD'),
#  ('1630', 'CD'),
#  ('at', 'IN'),
#  ('Shivneri', 'NNP'),
#  ('Fort', 'NNP'),
#  ('in', 'IN'),
#  ('Maharashtra', 'NNP'),
#  ('to', 'TO'),
#  ('Shahaji', 'NNP'),
#  ('Bhonsle', 'NNP'),
#  ('a', 'DT'),
#  ('Maratha', 'NNP'),
#  ('general', 'NN'),
#  ('and', 'CC'),
#  ('Jijabai', 'NNP'),
#  ('who', 'WP'),
#  ('deeply', 'RB'),
#  ('influenced', 'VBD'),
#  ('Shivaji', 'NNP'),
#  ('with', 'IN'),
#  ('her', 'PRP$'),
#  ('teachings', 'NNS'),
#  ('on', 'IN'),
#  ('dharma', 'NN'),
#  ('bravery', 'NN'),
#  ('and', 'CC'),
#  ('justice', 'NN'),
#  ('From', 'IN'),
#  ('an', 'DT'),
#  ('early', 'JJ'),
#  ('age', 'NN'),
#  ('Shivaji', 'NNP'),
#  ('exhibited', 'VBD'),
#  ('remarkable', 'JJ'),
#  ('leadership', 'NN'),
#  ('qualities', 'NNS'),
#  ('forming', 'VBG'),
#  ('a', 'DT'),
#  ('group', 'NN'),
#  ('of', 'IN'),
#  ('loyal', 'JJ'),
#  ('followers', 'NNS'),
#  ('and', 'CC'),
#  ('honing', 'VBG'),
#  ('his', 'PRP$'),
#  ('military', 'JJ'),
#  ('skills', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('rugged', 'JJ'),
#  ('terrain', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Sahyadri', 'NNP'),
#  ('mountains', 'NNS'),
#  ('He', 'PRP'),
#  ('grew', 'VBD'),
#  ('up', 'RP'),
#  ('during', 'IN'),
#  ('a', 'DT'),
#  ('time', 'NN'),
#  ('when', 'WRB'),
#  ('the', 'DT'),
#  ('Mughal', 'NNP'),
#  ('Empire', 'NNP'),
#  ('under', 'IN'),
#  ('Emperor', 'NNP'),
#  ('Aurangzeb', 'NNP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('Deccan', 'NNP'),
#  ('Sultanates', 'NNPS'),
#  ('were', 'VBD'),
#  ('vying', 'VBG'),
#  ('for', 'IN'),
#  ('control', 'NN'),
#  ('often', 'RB'),
#  ('oppressing', 'VBG'),
#  ('the', 'DT'),
#  ('local', 'JJ'),
#  ('population', 'NN'),
#  ('which', 'WDT'),
#  ('deeply', 'RB'),
#  ('disturbed', 'VBD'),
#  ('him', 'PRP'),
#  ('and', 'CC'),
#  ('fueled', 'VBD'),
#  ('his', 'PRP$'),
#  ('desire', 'NN'),
#  ('to', 'TO'),
#  ('establish', 'VB'),
#  ('Swarajya', 'NNP'),
#  ('or', 'CC'),
#  ('self-rule', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('Marathas', 'NNP'),
#  ('By', 'IN'),
#  ('the', 'DT'),
#  ('age', 'NN'),
#  ('of', 'IN'),
#  ('16', 'CD'),
#  ('Shivaji', 'NNP'),
#  ('had', 'VBD'),
#  ('captured', 'VBN'),
#  ('his', 'PRP$'),
#  ('first', 'JJ'),
#  ('fort', 'NN'),
#  ('Torna', 'NNP'),
#  ('using', 'VBG'),
#  ('guerrilla', 'NN'),
#  ('warfare', 'NN'),
#  ('tactics', 'NNS'),
#  ('that', 'WDT'),
#  ('would', 'MD'),
#  ('later', 'RB'),
#  ('become', 'VB'),
#  ('a', 'DT'),
#  ('hallmark', 'NN'),
#  ('of', 'IN'),
#  ('his', 'PRP$'),
#  ('military', 'JJ'),
#  ('strategy', 'NN'),
#  ('As', 'IN'),
#  ('his', 'PRP$'),
#  ('conquests', 'NNS'),
#  ('grew', 'VBD'),
#  ('he', 'PRP'),
#  ('formed', 'VBD'),
#  ('alliances', 'NNS'),
#  ('with', 'IN'),
#  ('local', 'JJ'),
#  ('leaders', 'NNS'),
#  ('securing', 'VBG'),
#  ('key', 'JJ'),
#  ('forts', 'NNS'),
#  ('like', 'IN'),
#  ('Raigad', 'NNP'),
#  ('Kondana', 'NNP'),
#  ('and', 'CC'),
#  ('Purandar', 'NNP'),
#  ('establishing', 'VBG'),
#  ('a', 'DT'),
#  ('solid', 'JJ'),
#  ('territorial', 'JJ'),
#  ('base', 'NN'),
#  ('in', 'IN'),
#  ('western', 'JJ'),
#  ('India', 'NNP'),
#  ('In', 'IN'),
#  ('1659', 'CD'),
#  ('he', 'PRP'),
#  ('faced', 'VBD'),
#  ('and', 'CC'),
#  ('defeated', 'VBD'),
#  ('Afzal', 'NNP'),
#  ('Khan', 'NNP'),
#  ('a', 'DT'),
#  ('prominent', 'JJ'),
#  ('general', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Bijapur', 'NNP'),
#  ('Sultanate', 'NNP'),
#  ('solidifying', 'VBG'),
#  ('his', 'PRP$'),
#  ('reputation', 'NN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('brave', 'NN'),
#  ('and', 'CC'),
#  ('tactical', 'JJ'),
#  ('leader', 'NN'),
#  ('this', 'DT'),
#  ('victory', 'NN'),
#  ('was', 'VBD'),
#  ('crucial', 'JJ'),
#  ('in', 'IN'),
#  ('establishing', 'VBG'),
#  ('his', 'PRP$'),
#  ('control', 'NN'),
#  ('over', 'IN'),
#  ('much', 'JJ'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Deccan', 'NNP'),
#  ('Shivaji', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'JJ'),
#  ('raids', 'NNS'),
#  ('on', 'IN'),
#  ('Mughal', 'NNP'),
#  ('territories', 'NNS'),
#  ('and', 'CC'),
#  ('his', 'PRP$'),
#  ('escape', 'NN'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('clutches', 'NNS'),
#  ('of', 'IN'),
#  ('Aurangzeb', 'NNP'),
#  ('in', 'IN'),
#  ('Agra', 'NNP'),
#  ('in', 'IN'),
#  ('1666', 'CD'),
#  ('further', 'RB'),
#  ('bolstered', 'VBD'),
#  ('his', 'PRP$'),
#  ('legend', 'NN'),
#  ('He', 'PRP'),
#  ('realized', 'VBD'),
#  ('that', 'IN'),
#  ('a', 'DT'),
#  ('powerful', 'JJ'),
#  ('navy', 'NN'),
#  ('was', 'VBD'),
#  ('crucial', 'JJ'),
#  ('to', 'TO'),
#  ('safeguard', 'VB'),
#  ('his', 'PRP$'),
#  ('territories', 'NNS'),
#  ('from', 'IN'),
#  ('foreign', 'JJ'),
#  ('invasions', 'NNS'),
#  ('leading', 'VBG'),
#  ('him', 'PRP'),
#  ('to', 'TO'),
#  ('develop', 'VB'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('earliest', 'JJS'),
#  ('organized', 'VBN'),
#  ('naval', 'JJ'),
#  ('forces', 'NNS'),
#  ('in', 'IN'),
#  ('India', 'NNP'),
#  ('allowing', 'VBG'),
#  ('him', 'PRP'),
#  ('to', 'TO'),
#  ('secure', 'VB'),
#  ('coastal', 'JJ'),
#  ('areas', 'NNS'),
#  ('against', 'IN'),
#  ('Portuguese', 'NNP'),
#  ('British', 'NNP'),
#  ('and', 'CC'),
#  ('Siddis', 'NNP'),
#  ('forces', 'NNS'),
#  ('In', 'IN'),
#  ('1674', 'CD'),
#  ('he', 'PRP'),
#  ('formally', 'RB'),
#  ('crowned', 'VBD'),
#  ('himself', 'PRP'),
#  ('as', 'IN'),
#  ('Chhatrapati', 'NNP'),
#  ('at', 'IN'),
#  ('Raigad', 'NNP'),
#  ('Fort', 'NNP'),
#  ('declaring', 'VBG'),
#  ('his', 'PRP$'),
#  ('independence', 'NN'),
#  ('and', 'CC'),
#  ('establishing', 'VBG'),
#  ('the', 'DT'),
#  ('Maratha', 'NNP'),
#  ('Empire', 'NNP'),
#  ('thus', 'RB'),
#  ('becoming', 'VBG'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('king', 'NN'),
#  ('to', 'TO'),
#  ('establish', 'VB'),
#  ('Hindavi', 'NNP'),
#  ('Swarajya', 'NNP'),
#  ('an', 'DT'),
#  ('autonomous', 'JJ'),
#  ('kingdom', 'NN'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('structured', 'JJ'),
#  ('administrative', 'JJ'),
#  ('framework', 'NN'),
#  ('rooted', 'VBN'),
#  ('in', 'IN'),
#  ('Indian', 'JJ'),
#  ('ethos', 'NN'),
#  ('Shivaji', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('administrative', 'JJ'),
#  ('system', 'NN'),
#  ('was', 'VBD'),
#  ('highly', 'RB'),
#  ('efficient', 'JJ'),
#  ('and', 'CC'),
#  ('he', 'PRP'),
#  ('emphasized', 'VBD'),
#  ('the', 'DT'),
#  ('welfare', 'NN'),
#  ('of', 'IN'),
#  ('his', 'PRP$'),
#  ('people', 'NNS'),
#  ('setting', 'VBG'),
#  ('up', 'RP'),
#  ('systems', 'NNS'),
#  ('to', 'TO'),
#  ('reduce', 'VB'),
#  ('corruption', 'NN'),
#  ('and', 'CC'),
#  ('create', 'VB'),
#  ('a', 'DT'),
#  ('fair', 'JJ'),
#  ('tax', 'NN'),
#  ('structure', 'NN'),
#  ('his', 'PRP$'),
#  ('Ashta', 'NNP'),
#  ('Pradhan', 'NNP'),
#  ('Council', 'NNP'),
#  ('of', 'IN'),
#  ('Eight', 'NNP'),
#  ('Ministers', 'NNP'),
#  ('included', 'VBD'),
#  ('departments', 'NNS'),
#  ('for', 'IN'),
#  ('finance', 'NN'),
#  ('internal', 'JJ'),
#  ('affairs', 'NNS'),
#  ('foreign', 'JJ'),
#  ('policy', 'NN'),
#  ('and', 'CC'),
#  ('military', 'JJ'),
#  ('to', 'TO'),
#  ('ensure', 'VB'),
#  ('smooth', 'JJ'),
#  ('governance', 'NN'),
#  ('Shivaji', 'NNP'),
#  ('showed', 'VBD'),
#  ('a', 'DT'),
#  ('progressive', 'JJ'),
#  ('approach', 'NN'),
#  ('towards', 'NNS'),
#  ('governance', 'NN'),
#  ('promoting', 'VBG'),
#  ('religious', 'JJ'),
#  ('tolerance', 'NN'),
#  ('and', 'CC'),
#  ('respecting', 'VBG'),
#  ('the', 'DT'),
#  ('diversity', 'NN'),
#  ('within', 'IN'),
#  ('his', 'PRP$'),
#  ('empire', 'NN'),
#  ('even', 'RB'),
#  ('appointing', 'VBG'),
#  ('Muslims', 'NNP'),
#  ('to', 'TO'),
#  ('key', 'VB'),
#  ('positions', 'NNS'),
#  ('in', 'IN'),
#  ('his', 'PRP$'),
#  ('administration', 'NN'),
#  ('and', 'CC'),
#  ('banning', 'VBG'),
#  ('the', 'DT'),
#  ('harassment', 'NN'),
#  ('of', 'IN'),
#  ('women', 'NNS'),
#  ('and', 'CC'),
#  ('looting', 'NN'),
#  ('of', 'IN'),
#  ('religious', 'JJ'),
#  ('sites', 'NNS'),
#  ('His', 'PRP$'),
#  ('respect', 'NN'),
#  ('for', 'IN'),
#  ('women', 'NNS'),
#  ('and', 'CC'),
#  ('his', 'PRP$'),
#  ('advocacy', 'NN'),
#  ('for', 'IN'),
#  ('justice', 'NN'),
#  ('inspired', 'VBN'),
#  ('trust', 'NN'),
#  ('and', 'CC'),
#  ('loyalty', 'NN'),
#  ('among', 'IN'),
#  ('his', 'PRP$'),
#  ('people', 'NNS'),
#  ('making', 'VBG'),
#  ('him', 'PRP'),
#  ('an', 'DT'),
#  ('ideal', 'NN'),
#  ('ruler', 'NN'),
#  ('for', 'IN'),
#  ('his', 'PRP$'),
#  ('time', 'NN'),
#  ('Shivaji', 'NNP'),
#  ('Maharaj', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('guerrilla', 'NN'),
#  ('tactics', 'NNS'),
#  ('known', 'VBN'),
#  ('as', 'IN'),
#  ('“', 'JJ'),
#  ('Ganimi', 'NNP'),
#  ('Kava', 'NNP'),
#  ('”', 'NNP'),
#  ('became', 'VBD'),
#  ('legendary', 'JJ'),
#  ('and', 'CC'),
#  ('enabled', 'VBD'),
#  ('him', 'PRP'),
#  ('to', 'TO'),
#  ('outmaneuver', 'VB'),
#  ('much', 'RB'),
#  ('larger', 'JJR'),
#  ('and', 'CC'),
#  ('better-equipped', 'JJ'),
#  ('armies', 'NNS'),
#  ('repeatedly', 'RB'),
#  ('allowing', 'VBG'),
#  ('him', 'PRP'),
#  ('to', 'TO'),
#  ('expand', 'VB'),
#  ('his', 'PRP$'),
#  ('empire', 'NN'),
#  ('while', 'IN'),
#  ('minimizing', 'VBG'),
#  ('losses', 'NNS'),
#  ('As', 'IN'),
#  ('his', 'PRP$'),
#  ('fame', 'NN'),
#  ('grew', 'VBD'),
#  ('the', 'DT'),
#  ('Maratha', 'NNP'),
#  ('Empire', 'NNP'),
#  ('began', 'VBD'),
#  ('to', 'TO'),
#  ('influence', 'VB'),
#  ('regions', 'NNS'),
#  ('far', 'RB'),
#  ('beyond', 'IN'),
#  ('Maharashtra', 'NNP'),
#  ('with', 'IN'),
#  ('Maratha', 'NNP'),
#  ('forces', 'NNS'),
#  ('eventually', 'RB'),
#  ('becoming', 'VBG'),
#  ('a', 'DT'),
#  ('significant', 'JJ'),
#  ('power', 'NN'),
#  ('across', 'IN'),
#  ('India', 'NNP'),
#  ('Shivaji', 'NNP'),
#  ('passed', 'VBD'),
#  ('away', 'RB'),
#  ('on', 'IN'),
#  ('April', 'NNP'),
#  ('3', 'CD'),
#  ('1680', 'CD'),
#  ('at', 'IN'),
#  ('Raigad', 'NNP'),
#  ('Fort', 'NNP'),
#  ('leaving', 'VBG'),
#  ('behind', 'IN'),
#  ('a', 'DT'),
#  ('powerful', 'JJ'),
#  ('legacy', 'NN'),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('well-organized', 'JJ'),
#  ('state', 'NN'),
#  ('that', 'WDT'),
#  ('continued', 'VBD'),
#  ('to', 'TO'),
#  ('expand', 'VB'),
#  ('after', 'IN'),
#  ('his', 'PRP$'),
#  ('death', 'NN'),
#  ('His', 'PRP$'),
#  ('life', 'NN'),
#  ('and', 'CC'),
#  ('ideals—valor', 'NN'),
#  ('respect', 'NN'),
#  ('for', 'IN'),
#  ('all', 'DT'),
#  ('faiths', 'NNS'),
#  ('and', 'CC'),
#  ('self-rule—continue', 'NN'),
#  ('to', 'TO'),
#  ('inspire', 'VB'),
#  ('millions', 'NNS'),
#  ('and', 'CC'),
#  ('his', 'PRP$'),
#  ('legacy', 'NN'),
#  ('endures', 'VBZ'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('form', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Maratha', 'NNP'),
#  ('Empire', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('contributions', 'NNS'),
#  ('to', 'TO'),
#  ('India', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'JJ'),
#  ('history', 'NN'),
#  ('and', 'CC'),
#  ('culture', 'NN')]

# %%
#Extract Nouns using SpaCy
nouns = [token.text for token in doc if token.pos_ == "NOUN"]
nouns
# Out:
# ['general',
#  'teachings',
#  'bravery',
#  'justice',
#  'age',
#  'leadership',
#  'qualities',
#  'group',
#  'followers',
#  'skills',
#  'terrain',
#  'mountains',
#  'time',
#  'control',
#  'population',
#  'desire',
#  'self',
#  'rule',
#  'age',
#  'fort',
#  'guerrilla',
#  'warfare',
#  'tactics',
#  'hallmark',
#  'strategy',
#  'conquests',
#  'alliances',
#  'leaders',
#  'forts',
#  'base',
#  'general',
#  'reputation',
#  'leader',
#  'victory',
#  'control',
#  'raids',
#  'territories',
#  'escape',
#  'clutches',
#  'legend',
#  'navy',
#  'territories',
#  'invasions',
#  'forces',
#  'areas',
#  'forces',
#  'independence',
#  'king',
#  'kingdom',
#  'framework',
#  'ethos',
#  'system',
#  'welfare',
#  'people',
#  'systems',
#  'corruption',
#  'tax',
#  'structure',
#  'departments',
#  'finance',
#  'affairs',
#  'policy',
#  'military',
#  'governance',
#  'approach',
#  'governance',
#  'tolerance',
#  'diversity',
#  'empire',
#  'positions',
#  'administration',
#  'harassment',
#  'women',
#  'looting',
#  'sites',
#  'respect',
#  'women',
#  'advocacy',
#  'justice',
#  'trust',
#  'loyalty',
#  'people',
#  'ruler',
#  'time',
#  'guerrilla',
#  'tactics',
#  'armies',
#  'empire',
#  'losses',
#  'fame',
#  'regions',
#  'forces',
#  'power',
#  'legacy',
#  'state',
#  'death',
#  'life',
#  'ideals',
#  'valor',
#  'respect',
#  'faiths',
#  'self',
#  'rule',
#  'millions',
#  'legacy',
#  'form',
#  'contributions',
#  'history',
#  'culture']

# %% [markdown]
# #4. Stop Words Removal
# NLTK Stop Words Removal:

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk
from nltk.corpus import stopwords
import spacy

# Stop Words Removal using NLTK
nltk_stopwords = set(stopwords.words('english'))
nltk_cleaned_text = ' '.join([word for word in text.split() if word.lower() not in nltk_stopwords])
print(nltk_cleaned_text)
# Out:
# Chhatrapati Shivaji Maharaj born February 19, 1630, Shivneri Fort Maharashtra, Shahaji Bhonsle, Maratha general, Jijabai, deeply influenced Shivaji teachings dharma, bravery, justice. early age, Shivaji exhibited remarkable leadership qualities, forming group loyal followers honing military skills rugged terrain Sahyadri mountains. grew time Mughal Empire Emperor Aurangzeb Deccan Sultanates vying control, often oppressing local population, deeply disturbed fueled desire establish Swarajya, self-rule Marathas. age 16, Shivaji captured first fort, Torna, using guerrilla warfare tactics would later become hallmark military strategy. conquests grew, formed alliances local leaders, securing key forts like Raigad, Kondana, Purandar, establishing solid territorial base western India. 1659, faced defeated Afzal Khan, prominent general Bijapur Sultanate, solidifying reputation brave tactical leader; victory crucial establishing control much Deccan. Shivaji’s raids Mughal territories escape clutches Aurangzeb Agra 1666 bolstered legend. realized powerful navy crucial safeguard territories foreign invasions, leading develop one earliest organized naval forces India, allowing secure coastal areas Portuguese, British, Siddis forces. 1674, formally crowned Chhatrapati Raigad Fort, declaring independence establishing Maratha Empire, thus becoming first king establish Hindavi Swarajya, autonomous kingdom structured administrative framework rooted Indian ethos. Shivaji’s administrative system highly efficient, emphasized welfare people, setting systems reduce corruption create fair tax structure; Ashta Pradhan (Council Eight Ministers) included departments finance, internal affairs, foreign policy, military ensure smooth governance. Shivaji showed progressive approach towards governance, promoting religious tolerance respecting diversity within empire, even appointing Muslims key positions administration banning harassment women looting religious sites. respect women advocacy justice inspired trust loyalty among people, making ideal ruler time. Shivaji Maharaj’s guerrilla tactics, known “Ganimi Kava,” became legendary enabled outmaneuver much larger better-equipped armies repeatedly, allowing expand empire minimizing losses. fame grew, Maratha Empire began influence regions far beyond Maharashtra, Maratha forces eventually becoming significant power across India. Shivaji passed away April 3, 1680, Raigad Fort, leaving behind powerful legacy well-organized state continued expand death. life ideals—valor, respect faiths, self-rule—continue inspire millions, legacy endures form Maratha Empire’s contributions India’s history culture.

# %%
# Load the spaCy model for English
nlp = spacy.load("en_core_web_sm")
doc = nlp(text)

# Remove stop words using spaCy
spacy_cleaned_text = ' '.join([token.text for token in doc if not token.is_stop])
print(spacy_cleaned_text)
# Out:
# Chhatrapati Shivaji Maharaj born February 19 , 1630 , Shivneri Fort Maharashtra , Shahaji Bhonsle , Maratha general , Jijabai , deeply influenced Shivaji teachings dharma , bravery , justice . early age , Shivaji exhibited remarkable leadership qualities , forming group loyal followers honing military skills rugged terrain Sahyadri mountains . grew time Mughal Empire Emperor Aurangzeb Deccan Sultanates vying control , oppressing local population , deeply disturbed fueled desire establish Swarajya , self - rule Marathas . age 16 , Shivaji captured fort , Torna , guerrilla warfare tactics later hallmark military strategy . conquests grew , formed alliances local leaders , securing key forts like Raigad , Kondana , Purandar , establishing solid territorial base western India . 1659 , faced defeated Afzal Khan , prominent general Bijapur Sultanate , solidifying reputation brave tactical leader ; victory crucial establishing control Deccan . Shivaji raids Mughal territories escape clutches Aurangzeb Agra 1666 bolstered legend . realized powerful navy crucial safeguard territories foreign invasions , leading develop earliest organized naval forces India , allowing secure coastal areas Portuguese , British , Siddis forces . 1674 , formally crowned Chhatrapati Raigad Fort , declaring independence establishing Maratha Empire , king establish Hindavi Swarajya , autonomous kingdom structured administrative framework rooted Indian ethos . Shivaji administrative system highly efficient , emphasized welfare people , setting systems reduce corruption create fair tax structure ; Ashta Pradhan ( Council Ministers ) included departments finance , internal affairs , foreign policy , military ensure smooth governance . Shivaji showed progressive approach governance , promoting religious tolerance respecting diversity empire , appointing Muslims key positions administration banning harassment women looting religious sites . respect women advocacy justice inspired trust loyalty people , making ideal ruler time . Shivaji Maharaj guerrilla tactics , known “ Ganimi Kava , ” legendary enabled outmaneuver larger better - equipped armies repeatedly , allowing expand empire minimizing losses . fame grew , Maratha Empire began influence regions far Maharashtra , Maratha forces eventually significant power India . Shivaji passed away April 3 , 1680 , Raigad Fort , leaving powerful legacy - organized state continued expand death . life ideals — valor , respect faiths , self - rule — continue inspire millions , legacy endures form Maratha Empire contributions India history culture .

# %% [markdown]
# #5. Lemmatization
# SpaCy Lemmatization:

# %%
lemmas = [token.lemma_ for token in doc]
print(lemmas)
# Out:
# ['Chhatrapati', 'Shivaji', 'Maharaj', 'be', 'bear', 'on', 'February', '19', ',', '1630', ',', 'at', 'Shivneri', 'Fort', 'in', 'Maharashtra', ',', 'to', 'Shahaji', 'Bhonsle', ',', 'a', 'Maratha', 'general', ',', 'and', 'Jijabai', ',', 'who', 'deeply', 'influence', 'Shivaji', 'with', 'her', 'teaching', 'on', 'dharma', ',', 'bravery', ',', 'and', 'justice', '.', 'from', 'an', 'early', 'age', ',', 'Shivaji', 'exhibit', 'remarkable', 'leadership', 'quality', ',', 'form', 'a', 'group', 'of', 'loyal', 'follower', 'and', 'hone', 'his', 'military', 'skill', 'in', 'the', 'rugged', 'terrain', 'of', 'the', 'Sahyadri', 'mountain', '.', 'he', 'grow', 'up', 'during', 'a', 'time', 'when', 'the', 'Mughal', 'Empire', 'under', 'Emperor', 'Aurangzeb', 'and', 'the', 'Deccan', 'Sultanates', 'be', 'vie', 'for', 'control', ',', 'often', 'oppress', 'the', 'local', 'population', ',', 'which', 'deeply', 'disturb', 'he', 'and', 'fuel', 'his', 'desire', 'to', 'establish', 'Swarajya', ',', 'or', 'self', '-', 'rule', 'for', 'the', 'Marathas', '.', 'by', 'the', 'age', 'of', '16', ',', 'Shivaji', 'have', 'capture', 'his', 'first', 'fort', ',', 'Torna', ',', 'use', 'guerrilla', 'warfare', 'tactic', 'that', 'would', 'later', 'become', 'a', 'hallmark', 'of', 'his', 'military', 'strategy', '.', 'as', 'his', 'conquest', 'grow', ',', 'he', 'form', 'alliance', 'with', 'local', 'leader', ',', 'secure', 'key', 'fort', 'like', 'Raigad', ',', 'Kondana', ',', 'and', 'Purandar', ',', 'establish', 'a', 'solid', 'territorial', 'base', 'in', 'western', 'India', '.', 'in', '1659', ',', 'he', 'face', 'and', 'defeat', 'Afzal', 'Khan', ',', 'a', 'prominent', 'general', 'of', 'the', 'Bijapur', 'Sultanate', ',', 'solidify', 'his', 'reputation', 'as', 'a', 'brave', 'and', 'tactical', 'leader', ';', 'this', 'victory', 'be', 'crucial', 'in', 'establish', 'his', 'control', 'over', 'much', 'of', 'the', 'Deccan', '.', 'Shivaji', '’s', 'raid', 'on', 'Mughal', 'territory', 'and', 'his', 'escape', 'from', 'the', 'clutch', 'of', 'Aurangzeb', 'in', 'Agra', 'in', '1666', 'far', 'bolster', 'his', 'legend', '.', 'he', 'realize', 'that', 'a', 'powerful', 'navy', 'be', 'crucial', 'to', 'safeguard', 'his', 'territory', 'from', 'foreign', 'invasion', ',', 'lead', 'he', 'to', 'develop', 'one', 'of', 'the', 'early', 'organize', 'naval', 'force', 'in', 'India', ',', 'allow', 'he', 'to', 'secure', 'coastal', 'area', 'against', 'Portuguese', ',', 'british', ',', 'and', 'Siddis', 'force', '.', 'in', '1674', ',', 'he', 'formally', 'crown', 'himself', 'as', 'Chhatrapati', 'at', 'Raigad', 'Fort', ',', 'declare', 'his', 'independence', 'and', 'establish', 'the', 'Maratha', 'Empire', ',', 'thus', 'become', 'the', 'first', 'king', 'to', 'establish', 'Hindavi', 'Swarajya', ',', 'an', 'autonomous', 'kingdom', 'with', 'a', 'structured', 'administrative', 'framework', 'root', 'in', 'indian', 'ethos', '.', 'Shivaji', '’s', 'administrative', 'system', 'be', 'highly', 'efficient', ',', 'and', 'he', 'emphasize', 'the', 'welfare', 'of', 'his', 'people', ',', 'set', 'up', 'system', 'to', 'reduce', 'corruption', 'and', 'create', 'a', 'fair', 'tax', 'structure', ';', 'his', 'Ashta', 'Pradhan', '(', 'Council', 'of', 'Eight', 'Ministers', ')', 'include', 'department', 'for', 'finance', ',', 'internal', 'affair', ',', 'foreign', 'policy', ',', 'and', 'military', 'to', 'ensure', 'smooth', 'governance', '.', 'Shivaji', 'show', 'a', 'progressive', 'approach', 'towards', 'governance', ',', 'promote', 'religious', 'tolerance', 'and', 'respect', 'the', 'diversity', 'within', 'his', 'empire', ',', 'even', 'appoint', 'Muslims', 'to', 'key', 'position', 'in', 'his', 'administration', 'and', 'ban', 'the', 'harassment', 'of', 'woman', 'and', 'looting', 'of', 'religious', 'site', '.', 'his', 'respect', 'for', 'woman', 'and', 'his', 'advocacy', 'for', 'justice', 'inspire', 'trust', 'and', 'loyalty', 'among', 'his', 'people', ',', 'make', 'he', 'an', 'ideal', 'ruler', 'for', 'his', 'time', '.', 'Shivaji', 'Maharaj', '’s', 'guerrilla', 'ta ...

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
#NLTK Lemmatization of Verbs:
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
lemmas_verbs = [lemmatizer.lemmatize(word, pos='v') for word in words if word.isalpha()]
print(lemmas_verbs)
# Out:
# ['Chhatrapati', 'Shivaji', 'Maharaj', 'be', 'bear', 'on', 'February', 'at', 'Shivneri', 'Fort', 'in', 'to', 'Shahaji', 'a', 'Maratha', 'and', 'who', 'deeply', 'influence', 'Shivaji', 'with', 'her', 'teach', 'on', 'and', 'From', 'an', 'early', 'Shivaji', 'exhibit', 'remarkable', 'leadership', 'form', 'a', 'group', 'of', 'loyal', 'followers', 'and', 'hone', 'his', 'military', 'skills', 'in', 'the', 'rugged', 'terrain', 'of', 'the', 'Sahyadri', 'He', 'grow', 'up', 'during', 'a', 'time', 'when', 'the', 'Mughal', 'Empire', 'under', 'Emperor', 'Aurangzeb', 'and', 'the', 'Deccan', 'Sultanates', 'be', 'vie', 'for', 'often', 'oppress', 'the', 'local', 'which', 'deeply', 'disturb', 'him', 'and', 'fuel', 'his', 'desire', 'to', 'establish', 'or', 'for', 'the', 'By', 'the', 'age', 'of', 'Shivaji', 'have', 'capture', 'his', 'first', 'use', 'guerrilla', 'warfare', 'tactics', 'that', 'would', 'later', 'become', 'a', 'hallmark', 'of', 'his', 'military', 'As', 'his', 'conquests', 'he', 'form', 'alliances', 'with', 'local', 'secure', 'key', 'fort', 'like', 'and', 'establish', 'a', 'solid', 'territorial', 'base', 'in', 'western', 'In', 'he', 'face', 'and', 'defeat', 'Afzal', 'a', 'prominent', 'general', 'of', 'the', 'Bijapur', 'solidify', 'his', 'reputation', 'as', 'a', 'brave', 'and', 'tactical', 'this', 'victory', 'be', 'crucial', 'in', 'establish', 'his', 'control', 'over', 'much', 'of', 'the', 'raid', 'on', 'Mughal', 'territories', 'and', 'his', 'escape', 'from', 'the', 'clutch', 'of', 'Aurangzeb', 'in', 'Agra', 'in', 'further', 'bolster', 'his', 'He', 'realize', 'that', 'a', 'powerful', 'navy', 'be', 'crucial', 'to', 'safeguard', 'his', 'territories', 'from', 'foreign', 'lead', 'him', 'to', 'develop', 'one', 'of', 'the', 'earliest', 'organize', 'naval', 'force', 'in', 'allow', 'him', 'to', 'secure', 'coastal', 'areas', 'against', 'and', 'Siddis', 'In', 'he', 'formally', 'crown', 'himself', 'as', 'Chhatrapati', 'at', 'Raigad', 'declare', 'his', 'independence', 'and', 'establish', 'the', 'Maratha', 'thus', 'become', 'the', 'first', 'king', 'to', 'establish', 'Hindavi', 'an', 'autonomous', 'kingdom', 'with', 'a', 'structure', 'administrative', 'framework', 'root', 'in', 'Indian', 'administrative', 'system', 'be', 'highly', 'and', 'he', 'emphasize', 'the', 'welfare', 'of', 'his', 'set', 'up', 'systems', 'to', 'reduce', 'corruption', 'and', 'create', 'a', 'fair', 'tax', 'his', 'Ashta', 'Pradhan', 'of', 'Eight', 'include', 'departments', 'for', 'internal', 'foreign', 'and', 'military', 'to', 'ensure', 'smooth', 'Shivaji', 'show', 'a', 'progressive', 'approach', 'towards', 'promote', 'religious', 'tolerance', 'and', 'respect', 'the', 'diversity', 'within', 'his', 'even', 'appoint', 'Muslims', 'to', 'key', 'position', 'in', 'his', 'administration', 'and', 'ban', 'the', 'harassment', 'of', 'women', 'and', 'loot', 'of', 'religious', 'His', 'respect', 'for', 'women', 'and', 'his', 'advocacy', 'for', 'justice', 'inspire', 'trust', 'and', 'loyalty', 'among', 'his', 'make', 'him', 'an', 'ideal', 'ruler', 'for', 'his', 'Shivaji', 'guerrilla', 'know', 'as', 'become', 'legendary', 'and', 'enable', 'him', 'to', 'outmaneuver', 'much', 'larger', 'and', 'armies', 'allow', 'him', 'to', 'expand', 'his', 'empire', 'while', 'minimize', 'As', 'his', 'fame', 'the', 'Maratha', 'Empire', 'begin', 'to', 'influence', 'regions', 'far', 'beyond', 'with', 'Maratha', 'force', 'eventually', 'become', 'a', 'significant', 'power', 'across', 'Shivaji', 'pass', 'away', 'on', 'April', 'at', 'Raigad', 'leave', 'behind', 'a', 'powerful', 'legacy', 'and', 'a', 'state', 'that', 'continue', 'to', 'expand', 'after', 'his', 'His', 'life', 'and', 'respect', 'for', 'all', 'and', 'to', 'inspire', 'and', 'his', 'legacy', 'endure', 'in', 'the', 'form', 'of', 'the', 'Maratha', 'contributions', 'to', 'history', 'and']

# %% [markdown]
# #6. Sentiment Analysis

# %%
#TextBlob Sentiment Analysis:
sentiment = blob.sentiment
print(sentiment)
# Out:
# Sentiment(polarity=0.15890070921985816, subjectivity=0.5364893617021277)

# %%
#Sentence-wise Sentiment Analysis:
for sentence in sentences:
    print(sentence, TextBlob(sentence).sentiment)
# Out:
# Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings on dharma, bravery, and justice. Sentiment(polarity=0.02500000000000001, subjectivity=0.45)
# From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains. Sentiment(polarity=0.2708333333333333, subjectivity=0.49583333333333335)
# He grew up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates were vying for control, often oppressing the local population, which deeply disturbed him and fueled his desire to establish Swarajya, or self-rule for the Marathas. Sentiment(polarity=0.0, subjectivity=0.2)
# By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy. Sentiment(polarity=0.049999999999999996, subjectivity=0.14444444444444446)
# As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India. Sentiment(polarity=-0.16, subjectivity=0.42000000000000004)
# In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan. Sentiment(polarity=0.31, subjectivity=0.74)
# Shivaji’s raids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolstered his legend. Sentiment(polarity=0.0, subjectivity=0.5)
# He realized that a powerful navy was crucial to safeguard his territories from foreign invasions, leading him to develop one of the earliest organized naval forces in India, allowing him to secure coastal areas against Portuguese, British, and Siddis forces. Sentiment(polarity=0.11499999999999999, subjectivity=0.545)
# In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos. Sentiment(polarity=0.3666666666666667, subjectivity=0.6277777777777778)
# Shivaji’s administrative system was highly efficient, and he emphasized the welfare of his people, setting up systems to reduce corruption and create a fair tax structure; his Ashta Pradhan (Council of Eight Ministers) included departments for finance, internal affairs, foreign policy, and military to ensure smooth governance. Sentiment(polarity=0.17250000000000001, subjectivity=0.36083333333333334)
# Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites. Sentiment(polarity=0.0, subjectivity=0.5)
# His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time. Sentiment(polarity=0.9, subjectivity=1.0)
# Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legendary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses. Sentiment(polarity=0.5, subjectivity=0.75)
# As his fame grew, the Maratha Empire began to influence regions far beyond Maharashtra, with Maratha forces eventually becoming a significant power across India. Sentiment(polarity=0.30833333333333335, subjectivity=0.9083333333333333)
# Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death. Sentiment(polarity=-0.05000000000000002, subjectivity=0.85)
# His life and ideals—valor, respect for all faiths, and self-rule—continue to inspire millions, and his legacy endures in the form of the Maratha Empire’s contributions to India’s history and culture. Sentiment(polarity=0.0, subjectivity=0.0)

# %% [markdown]
# #7. N-Grams

# %%
#Generate Bigrams using NLTK:
from nltk import ngrams

bigrams = list(ngrams(words, 2))
print(bigrams)
# Out:
# [('Chhatrapati', 'Shivaji'), ('Shivaji', 'Maharaj'), ('Maharaj', 'was'), ('was', 'born'), ('born', 'on'), ('on', 'February'), ('February', '19,'), ('19,', '1630,'), ('1630,', 'at'), ('at', 'Shivneri'), ('Shivneri', 'Fort'), ('Fort', 'in'), ('in', 'Maharashtra,'), ('Maharashtra,', 'to'), ('to', 'Shahaji'), ('Shahaji', 'Bhonsle,'), ('Bhonsle,', 'a'), ('a', 'Maratha'), ('Maratha', 'general,'), ('general,', 'and'), ('and', 'Jijabai,'), ('Jijabai,', 'who'), ('who', 'deeply'), ('deeply', 'influenced'), ('influenced', 'Shivaji'), ('Shivaji', 'with'), ('with', 'her'), ('her', 'teachings'), ('teachings', 'on'), ('on', 'dharma,'), ('dharma,', 'bravery,'), ('bravery,', 'and'), ('and', 'justice.'), ('justice.', 'From'), ('From', 'an'), ('an', 'early'), ('early', 'age,'), ('age,', 'Shivaji'), ('Shivaji', 'exhibited'), ('exhibited', 'remarkable'), ('remarkable', 'leadership'), ('leadership', 'qualities,'), ('qualities,', 'forming'), ('forming', 'a'), ('a', 'group'), ('group', 'of'), ('of', 'loyal'), ('loyal', 'followers'), ('followers', 'and'), ('and', 'honing'), ('honing', 'his'), ('his', 'military'), ('military', 'skills'), ('skills', 'in'), ('in', 'the'), ('the', 'rugged'), ('rugged', 'terrain'), ('terrain', 'of'), ('of', 'the'), ('the', 'Sahyadri'), ('Sahyadri', 'mountains.'), ('mountains.', 'He'), ('He', 'grew'), ('grew', 'up'), ('up', 'during'), ('during', 'a'), ('a', 'time'), ('time', 'when'), ('when', 'the'), ('the', 'Mughal'), ('Mughal', 'Empire'), ('Empire', 'under'), ('under', 'Emperor'), ('Emperor', 'Aurangzeb'), ('Aurangzeb', 'and'), ('and', 'the'), ('the', 'Deccan'), ('Deccan', 'Sultanates'), ('Sultanates', 'were'), ('were', 'vying'), ('vying', 'for'), ('for', 'control,'), ('control,', 'often'), ('often', 'oppressing'), ('oppressing', 'the'), ('the', 'local'), ('local', 'population,'), ('population,', 'which'), ('which', 'deeply'), ('deeply', 'disturbed'), ('disturbed', 'him'), ('him', 'and'), ('and', 'fueled'), ('fueled', 'his'), ('his', 'desire'), ('desire', 'to'), ('to', 'establish'), ('establish', 'Swarajya,'), ('Swarajya,', 'or'), ('or', 'self-rule'), ('self-rule', 'for'), ('for', 'the'), ('the', 'Marathas.'), ('Marathas.', 'By'), ('By', 'the'), ('the', 'age'), ('age', 'of'), ('of', '16,'), ('16,', 'Shivaji'), ('Shivaji', 'had'), ('had', 'captured'), ('captured', 'his'), ('his', 'first'), ('first', 'fort,'), ('fort,', 'Torna,'), ('Torna,', 'using'), ('using', 'guerrilla'), ('guerrilla', 'warfare'), ('warfare', 'tactics'), ('tactics', 'that'), ('that', 'would'), ('would', 'later'), ('later', 'become'), ('become', 'a'), ('a', 'hallmark'), ('hallmark', 'of'), ('of', 'his'), ('his', 'military'), ('military', 'strategy.'), ('strategy.', 'As'), ('As', 'his'), ('his', 'conquests'), ('conquests', 'grew,'), ('grew,', 'he'), ('he', 'formed'), ('formed', 'alliances'), ('alliances', 'with'), ('with', 'local'), ('local', 'leaders,'), ('leaders,', 'securing'), ('securing', 'key'), ('key', 'forts'), ('forts', 'like'), ('like', 'Raigad,'), ('Raigad,', 'Kondana,'), ('Kondana,', 'and'), ('and', 'Purandar,'), ('Purandar,', 'establishing'), ('establishing', 'a'), ('a', 'solid'), ('solid', 'territorial'), ('territorial', 'base'), ('base', 'in'), ('in', 'western'), ('western', 'India.'), ('India.', 'In'), ('In', '1659,'), ('1659,', 'he'), ('he', 'faced'), ('faced', 'and'), ('and', 'defeated'), ('defeated', 'Afzal'), ('Afzal', 'Khan,'), ('Khan,', 'a'), ('a', 'prominent'), ('prominent', 'general'), ('general', 'of'), ('of', 'the'), ('the', 'Bijapur'), ('Bijapur', 'Sultanate,'), ('Sultanate,', 'solidifying'), ('solidifying', 'his'), ('his', 'reputation'), ('reputation', 'as'), ('as', 'a'), ('a', 'brave'), ('brave', 'and'), ('and', 'tactical'), ('tactical', 'leader;'), ('leader;', 'this'), ('this', 'victory'), ('victory', 'was'), ('was', 'crucial'), ('crucial', 'in'), ('in', 'establishing'), ('establishing', 'his'), ('his', 'control'), ('control', 'over'), ('over', 'much'), ('much', 'of'), ('of', 'the'), ('the', 'Deccan.'), ('Deccan.', 'Shivaji’s' ...

# %%
#Generate Trigrams using TextBlob:
trigrams = list(ngrams(words, 3))
print(trigrams)
# Out:
# [('Chhatrapati', 'Shivaji', 'Maharaj'), ('Shivaji', 'Maharaj', 'was'), ('Maharaj', 'was', 'born'), ('was', 'born', 'on'), ('born', 'on', 'February'), ('on', 'February', '19,'), ('February', '19,', '1630,'), ('19,', '1630,', 'at'), ('1630,', 'at', 'Shivneri'), ('at', 'Shivneri', 'Fort'), ('Shivneri', 'Fort', 'in'), ('Fort', 'in', 'Maharashtra,'), ('in', 'Maharashtra,', 'to'), ('Maharashtra,', 'to', 'Shahaji'), ('to', 'Shahaji', 'Bhonsle,'), ('Shahaji', 'Bhonsle,', 'a'), ('Bhonsle,', 'a', 'Maratha'), ('a', 'Maratha', 'general,'), ('Maratha', 'general,', 'and'), ('general,', 'and', 'Jijabai,'), ('and', 'Jijabai,', 'who'), ('Jijabai,', 'who', 'deeply'), ('who', 'deeply', 'influenced'), ('deeply', 'influenced', 'Shivaji'), ('influenced', 'Shivaji', 'with'), ('Shivaji', 'with', 'her'), ('with', 'her', 'teachings'), ('her', 'teachings', 'on'), ('teachings', 'on', 'dharma,'), ('on', 'dharma,', 'bravery,'), ('dharma,', 'bravery,', 'and'), ('bravery,', 'and', 'justice.'), ('and', 'justice.', 'From'), ('justice.', 'From', 'an'), ('From', 'an', 'early'), ('an', 'early', 'age,'), ('early', 'age,', 'Shivaji'), ('age,', 'Shivaji', 'exhibited'), ('Shivaji', 'exhibited', 'remarkable'), ('exhibited', 'remarkable', 'leadership'), ('remarkable', 'leadership', 'qualities,'), ('leadership', 'qualities,', 'forming'), ('qualities,', 'forming', 'a'), ('forming', 'a', 'group'), ('a', 'group', 'of'), ('group', 'of', 'loyal'), ('of', 'loyal', 'followers'), ('loyal', 'followers', 'and'), ('followers', 'and', 'honing'), ('and', 'honing', 'his'), ('honing', 'his', 'military'), ('his', 'military', 'skills'), ('military', 'skills', 'in'), ('skills', 'in', 'the'), ('in', 'the', 'rugged'), ('the', 'rugged', 'terrain'), ('rugged', 'terrain', 'of'), ('terrain', 'of', 'the'), ('of', 'the', 'Sahyadri'), ('the', 'Sahyadri', 'mountains.'), ('Sahyadri', 'mountains.', 'He'), ('mountains.', 'He', 'grew'), ('He', 'grew', 'up'), ('grew', 'up', 'during'), ('up', 'during', 'a'), ('during', 'a', 'time'), ('a', 'time', 'when'), ('time', 'when', 'the'), ('when', 'the', 'Mughal'), ('the', 'Mughal', 'Empire'), ('Mughal', 'Empire', 'under'), ('Empire', 'under', 'Emperor'), ('under', 'Emperor', 'Aurangzeb'), ('Emperor', 'Aurangzeb', 'and'), ('Aurangzeb', 'and', 'the'), ('and', 'the', 'Deccan'), ('the', 'Deccan', 'Sultanates'), ('Deccan', 'Sultanates', 'were'), ('Sultanates', 'were', 'vying'), ('were', 'vying', 'for'), ('vying', 'for', 'control,'), ('for', 'control,', 'often'), ('control,', 'often', 'oppressing'), ('often', 'oppressing', 'the'), ('oppressing', 'the', 'local'), ('the', 'local', 'population,'), ('local', 'population,', 'which'), ('population,', 'which', 'deeply'), ('which', 'deeply', 'disturbed'), ('deeply', 'disturbed', 'him'), ('disturbed', 'him', 'and'), ('him', 'and', 'fueled'), ('and', 'fueled', 'his'), ('fueled', 'his', 'desire'), ('his', 'desire', 'to'), ('desire', 'to', 'establish'), ('to', 'establish', 'Swarajya,'), ('establish', 'Swarajya,', 'or'), ('Swarajya,', 'or', 'self-rule'), ('or', 'self-rule', 'for'), ('self-rule', 'for', 'the'), ('for', 'the', 'Marathas.'), ('the', 'Marathas.', 'By'), ('Marathas.', 'By', 'the'), ('By', 'the', 'age'), ('the', 'age', 'of'), ('age', 'of', '16,'), ('of', '16,', 'Shivaji'), ('16,', 'Shivaji', 'had'), ('Shivaji', 'had', 'captured'), ('had', 'captured', 'his'), ('captured', 'his', 'first'), ('his', 'first', 'fort,'), ('first', 'fort,', 'Torna,'), ('fort,', 'Torna,', 'using'), ('Torna,', 'using', 'guerrilla'), ('using', 'guerrilla', 'warfare'), ('guerrilla', 'warfare', 'tactics'), ('warfare', 'tactics', 'that'), ('tactics', 'that', 'would'), ('that', 'would', 'later'), ('would', 'later', 'become'), ('later', 'become', 'a'), ('become', 'a', 'hallmark'), ('a', 'hallmark', 'of'), ('hallmark', 'of', 'his'), ('of', 'his', 'military'), ('his', 'military', 'strategy.'), ('military', 'strategy.', 'As'), ('strategy.', 'As', 'his'), ('As', 'his', 'conquests'), ('his', 'conquests', 'grew,'), ('conquests', 'grew,', 'he'), ('grew,', 'h ...

# %% [markdown]
# #8. Frequency Distribution

# %%
#NLTK Frequency Distribution:
from nltk import FreqDist

fdist = FreqDist(words)
print(fdist.most_common(5))
# Out:
# [('and', 26), ('his', 22), ('the', 19), ('to', 15), ('a', 14)]

# %%
#Most Common Nouns using SpaCy:
noun_freq = FreqDist([token.text for token in doc if token.pos_ == "NOUN"])
print(noun_freq.most_common(5))
# Out:
# [('forces', 3), ('general', 2), ('justice', 2), ('age', 2), ('time', 2)]

# %% [markdown]
# #9. Dependency Parsing

# %%
#Dependency Parse Information:
for sent in doc.sents:
    for token in sent:
        print(token.text, token.dep_, token.head.text)
# Out:
# Chhatrapati compound Maharaj
# Shivaji compound Maharaj
# Maharaj nsubjpass born
# was auxpass born
# born ROOT born
# on prep born
# February pobj on
# 19 nummod February
# , punct February
# 1630 nummod February
# , punct February
# at prep February
# Shivneri compound Fort
# Fort pobj at
# in prep Fort
# Maharashtra pobj in
# , punct February
# to prep born
# Shahaji compound Bhonsle
# Bhonsle pobj to
# , punct Bhonsle
# a det general
# Maratha compound general
# general appos Bhonsle
# , punct general
# and cc general
# Jijabai conj general
# , punct general
# who nsubj influenced
# deeply advmod influenced
# influenced relcl general
# Shivaji dobj influenced
# with prep influenced
# her poss teachings
# teachings pobj with
# on prep teachings
# dharma pobj on
# , punct dharma
# bravery conj dharma
# , punct bravery
# and cc bravery
# justice conj bravery
# . punct born
# From prep exhibited
# an det age
# early amod age
# age pobj From
# , punct exhibited
# Shivaji nsubj exhibited
# exhibited ROOT exhibited
# remarkable amod qualities
# leadership compound qualities
# qualities dobj exhibited
# , punct exhibited
# forming advcl exhibited
# a det group
# group dobj forming
# of prep group
# loyal amod followers
# followers pobj of
# and cc forming
# honing conj forming
# his poss skills
# military amod skills
# skills dobj honing
# in prep honing
# the det terrain
# rugged amod terrain
# terrain pobj in
# of prep terrain
# the det mountains
# Sahyadri compound mountains
# mountains pobj of
# . punct exhibited
# He nsubj grew
# grew ROOT grew
# up prt grew
# during prep grew
# a det time
# time pobj during
# when advmod vying
# the det Empire
# Mughal compound Empire
# Empire nsubj vying
# under prep Empire
# Emperor compound Aurangzeb
# Aurangzeb pobj under
# and cc Empire
# the det Sultanates
# Deccan compound Sultanates
# Sultanates conj Empire
# were aux vying
# vying relcl time
# for prep vying
# control pobj for
# , punct grew
# often advmod oppressing
# oppressing advcl grew
# the det population
# local amod population
# population dobj oppressing
# , punct population
# which nsubj disturbed
# deeply advmod disturbed
# disturbed relcl population
# him dobj disturbed
# and cc disturbed
# fueled conj disturbed
# his poss desire
# desire dobj fueled
# to aux establish
# establish acl desire
# Swarajya dobj establish
# , punct Swarajya
# or cc Swarajya
# self compound rule
# - punct rule
# rule conj Swarajya
# for prep rule
# the det Marathas
# Marathas pobj for
# . punct grew
# By prep captured
# the det age
# age pobj By
# of prep age
# 16 pobj of
# , punct captured
# Shivaji nsubj captured
# had aux captured
# captured ROOT captured
# his poss fort
# first amod fort
# fort dobj captured
# , punct fort
# Torna appos fort
# , punct fort
# using advcl captured
# guerrilla compound tactics
# warfare compound tactics
# tactics dobj using
# that nsubj become
# would aux become
# later advmod become
# become relcl tactics
# a det hallmark
# hallmark attr become
# of prep hallmark
# his poss strategy
# military amod strategy
# strategy pobj of
# . punct captured
# As mark grew
# his poss conquests
# conquests nsubj grew
# grew advcl formed
# , punct formed
# he nsubj formed
# formed ROOT formed
# alliances dobj formed
# with prep alliances
# local amod leaders
# leaders pobj with
# , punct formed
# securing advcl formed
# key amod forts
# forts dobj securing
# like prep forts
# Raigad pobj like
# , punct Raigad
# Kondana conj Raigad
# , punct Kondana
# and cc Kondana
# Purandar conj Kondana
# , punct securing
# establishing conj securing
# a det base
# solid amod base
# territorial amod base
# base dobj establishing
# in prep base
# western amod India
# India pobj in
# . punct formed
# In prep faced
# 1659 pobj In
# , punct faced
# he nsubj faced
# faced ccomp was
# and cc faced
# defeated conj faced
# Afzal compound Khan
# Khan dobj defeated
# , punct Khan
# a det general
# prominent amod general
# general appos Khan
# of prep general
# the det Sultanate
# Bijapur compound Sultanate
# Sultanate pobj of
# , punct Khan
# solidifying advcl defeated
# his poss reputation
# reputation dobj solidifying
# as prep reputation
# a det leader
# brave amod leader
# and cc brave
# tactical conj brave
# leader pobj as
# ; punct was
# this det victory
# victory nsubj was
# was ROOT was
# crucial acomp was
# in prep was
# establishing pcomp in
# his poss control
# control dobj establishing
# over prep establishing
# much pobj over
# of prep much
# the det Deccan
# Deccan pobj of
# . punct was
# Shivaji poss raids
# ’s case Shivaji
# raids nsubj bolstered
# on prep raids
# Mughal amod territories
# territories pobj on
# and cc raids
# his poss escape
# escape conj raids
# from prep escape
# the det clutches
# clutches pobj from
# of prep clutches
# Aurangzeb pobj of
# in prep clutches
# Agra pobj in
# in prep escape
# 1666 pobj in
# further advmod bolstered
# bolstered ROOT bolstered
# his poss legend
# legend dobj bolstered
# . punct bolstered
# He nsubj realized
# realized ROOT realized
# that mark was
# a det navy
# powerful amod navy
# navy nsubj was
# was ccomp realized
# crucial acomp was
# to aux safeguard
# safeguard xcomp was
# his poss territories
# territories dobj safeguard
# from prep safeguard
# foreign amod invasions
# invasions pobj from
# , punct was
# leading advcl was
# him dobj leading
# to aux develop
# develop xcomp leading
# one dobj develop
# of prep one
# the det forces
# earliest amod forces
# organized amod forces
# naval amod forces
# forces pobj of
# in prep forces
# India pobj in
# , punct develop
# allowing advcl develop
# him nsubj secure
# to aux secure
# secure ccomp allowing
# coastal amod areas
# areas dobj secure
# against prep areas
# Portuguese nmod forces
# , punct Portuguese
# British conj Portuguese
# , punct British
# and cc British
# Siddis compound forces
# forces pobj against
# . punct realized
# In prep crowned
# 1674 pobj In
# , punct crowned
# he nsubj crowned
# formally advmod crowned
# crowned ROOT crowned
# himself dobj crowned
# as prep crowned
# Chhatrapati pobj as
# at prep Chhatrapati
# Raigad compound Fort
# Fort pobj at
# , punct crowned
# declaring advcl crowned
# his poss independence
# independence dobj declaring
# and cc declaring
# establishing conj declaring
# the det Empire
# Maratha compound Empire
# Empire dobj establishing
# , punct declaring
# thus advmod becoming
# becoming advcl declaring
# the det king
# first amod king
# king attr becoming
# to aux establish
# establish advcl becoming
# Hindavi compound Swarajya
# Swarajya dobj establish
# , punct Swarajya
# an det kingdom
# autonomous amod kingdom
# kingdom appos Swarajya
# with prep kingdom
# a det framework
# structured amod framework
# administrative amod framework
# framework pobj with
# rooted acl framework
# in prep rooted
# Indian amod ethos
# ethos pobj in
# . punct crowned
# Shivaji poss system
# ’s case Shivaji
# administrative amod system
# system nsubj was
# was ccomp included
# highly advmod efficient
# efficient acomp was
# , punct was
# and cc was
# he nsubj emphasized
# emphasized conj was
# the det welfare
# welfare dobj emphasized
# of prep welfare
# his poss people
# people pobj of
# , punct emphasized
# setting advcl emphasized
# up prt setting
# systems dobj setting
# to aux reduce
# reduce advcl setting
# corruption dobj reduce
# and cc reduce
# create conj reduce
# a det structure
# fair amod structure
# tax compound structure
# structure dobj create
# ; punct included
# his poss Pradhan
# Ashta compound Pradhan
# Pradhan nsubj included
# ( punct Pradhan
# Council appos Pradhan
# of prep Council
# Eight compound Ministers
# Ministers pobj of
# ) punct Pradhan
# included ROOT included
# departments dobj included
# for prep departments
# finance pobj for
# , punct finance
# internal amod affairs
# affairs conj finance
# , punct affairs
# foreign amod policy
# policy conj affairs
# , punct policy
# and cc policy
# military conj policy
# to aux ensure
# ensure advcl included
# smooth amod governance
# governance dobj ensure
# . punct included
# Shivaji nsubj showed
# showed ROOT showed
# a det approach
# progressive amod approach
# approach dobj showed
# towards prep approach
# governance pobj towards
# , punct showed
# promoting advcl showed
# religious amod tolerance
# tolerance dobj promoting
# and cc promoting
# respecting conj promoting
# the det diversity
# diversity dobj respecting
# within prep respecting
# his poss empire
# empire pobj within
# , punct promoting
# even advmod appointing
# appointing conj promoting
# Muslims dobj appointing
# to prep appointing
# key amod positions
# positions pobj to
# in prep positions
# his poss administration
# administration pobj in
# and cc appointing
# banning conj appointing
# the det harassment
# harassment dobj banning
# of prep harassment
# women pobj of
# and cc harassment
# looting conj harassment
# of prep looting
# religious amod sites
# sites pobj of
# . punct showed
# His poss respect
# respect nsubj inspired
# for prep respect
# women pobj for
# and cc women
# his poss advocacy
# advocacy conj women
# for prep advocacy
# justice pobj for
# inspired ROOT inspired
# trust dobj inspired
# and cc trust
# loyalty conj trust
# among prep trust
# his poss people
# people pobj among
# , punct inspired
# making advcl inspired
# him nsubj ruler
# an det ruler
# ideal amod ruler
# ruler ccomp making
# for prep ruler
# his poss time
# time pobj for
# . punct inspired
# Shivaji compound Maharaj
# Maharaj poss tactics
# ’s case Maharaj
# guerrilla compound tactics
# tactics nsubj became
# , punct tactics
# known acl tactics
# as prep known
# “ punct as
# Ganimi compound Kava
# Kava pobj as
# , punct tactics
# ” punct tactics
# became ROOT became
# legendary acomp became
# and cc became
# enabled conj became
# him dobj enabled
# to aux outmaneuver
# outmaneuver xcomp enabled
# much advmod larger
# larger amod armies
# and cc larger
# better advmod equipped
# - punct equipped
# equipped conj larger
# armies dobj outmaneuver
# repeatedly advmod outmaneuver
# , punct enabled
# allowing advcl enabled
# him nsubj expand
# to aux expand
# expand ccomp allowing
# his poss empire
# empire dobj expand
# while mark minimizing
# minimizing advcl expand
# losses dobj minimizing
# . punct became
# As mark grew
# his poss fame
# fame nsubj grew
# grew advcl began
# , punct began
# the det Empire
# Maratha compound Empire
# Empire nsubj began
# began ROOT began
# to aux influence
# influence xcomp began
# regions dobj influence
# far advmod beyond
# beyond prep influence
# Maharashtra pobj beyond
# , punct influence
# with prep influence
# Maratha compound forces
# forces nsubj becoming
# eventually advmod becoming
# becoming pcomp with
# a det power
# significant amod power
# power attr becoming
# across prep power
# India pobj across
# . punct began
# Shivaji nsubj passed
# passed ROOT passed
# away prt passed
# on prep passed
# April pobj on
# 3 nummod April
# , punct April
# 1680 nummod April
# , punct April
# at prep passed
# Raigad compound Fort
# Fort pobj at
# , punct passed
# leaving advcl passed
# behind advmod leaving
# a det legacy
# powerful amod legacy
# legacy dobj leaving
# and cc legacy
# a det state
# well advmod organized
# - punct organized
# organized amod state
# state conj legacy
# that nsubj continued
# continued relcl state
# to aux expand
# expand xcomp continued
# after prep expand
# his poss death
# death pobj after
# . punct passed
# His poss life
# life nsubj continue
# and cc life
# ideals conj life
# — punct life
# valor appos life
# , punct valor
# respect appos life
# for prep respect
# all det faiths
# faiths pobj for
# , punct respect
# and cc respect
# self compound rule
# - punct rule
# rule conj respect
# — punct continue
# continue ROOT continue
# to aux inspire
# inspire xcomp continue
# millions dobj inspire
# , punct continue
# and cc continue
# his poss legacy
# legacy nsubj endures
# endures conj continue
# in prep endures
# the det form
# form pobj in
# of prep form
# the det Empire
# Maratha compound Empire
# Empire poss contributions
# ’s case Empire
# contributions pobj of
# to prep contributions
# India poss history
# ’s case India
# history pobj to
# and cc history
# culture conj history
# . punct endures

# %%
#Visualize the dependency tree of the first sentence using spaCy’s displacy tool.
from spacy import displacy

first_sentence = list(doc.sents)[0]
displacy.render(first_sentence, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="538290b636d9420e8d018496b38fe246-0" class="displacy" width="6000" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Chhatrapati</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Shivaji</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Maharaj</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">born</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">February</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">19,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">1630,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Shivneri</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">Fort</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">Maharashtra,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">Shahaji</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">Bhonsle,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">Maratha</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">general,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">Jijabai,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">who</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">deeply</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">influenced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">Shivaji</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">her</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">teachings</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">dharma,</tspan>
#     <tspan class="displac

# %% [markdown]
# #10. Phrase Matching

# %%
#Identify Occurrences of "Maratha Empire":
from spacy.matcher import PhraseMatcher

matcher = PhraseMatcher(nlp.vocab)
matcher.add("Maratha Empire", [nlp("Maratha Empire")])
matches = matcher(doc)
print(matches)
# Out:
# [(10435079259162002481, 313, 315), (10435079259162002481, 507, 509), (10435079259162002481, 591, 593)]

# %%
#Find Patterns with Shivaji Maharaj:
from spacy.matcher import Matcher

matcher = Matcher(nlp.vocab)
pattern = [{"LOWER": "shivaji"}, {"LOWER": "maharaj"}, {"IS_ALPHA": True}]
matcher.add("Shivaji Actions", [pattern])
matches = matcher(doc)
print(matches)
# Out:
# [(9791122795303640679, 1, 4)]

# %% [markdown]
# #11. Sentence Similarity

# %%
#Calculate Similarity:
doc = nlp(sentences[0])
doc1 = nlp(sentences[1])
similarity = doc.similarity(doc1)
print(similarity)
# Out:
# 0.5305717848712475
# <ipython-input-59-395689278e28>:4: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   similarity = doc.similarity(doc1)

# %%
#TextBlob Similarity:
from textblob import TextBlob

blob1 = TextBlob(sentences[0])
blob2 = TextBlob(sentences[1])
similarity = blob1.sentiment.polarity - blob2.sentiment.polarity
print(similarity)
# Out:
# -0.2458333333333333

# %% [markdown]
# #12. Translation

# %%
# !pip install deep_translator
# Out:
# Collecting deep_translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from deep_translator) (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from deep_translator) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep_translator) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2024.8.30)
# Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: deep_translator
# Successfully installed deep_translator-1.11.4

# %%
# Translate the text into Hindi
from deep_translator import GoogleTranslator

translated_text = GoogleTranslator(source='en', target='hi').translate(text)
translated_text
# Out:
# 'छत्रपति शिवाजी महाराज का जन्म 19 फरवरी, 1630 को महाराष्ट्र के शिवनेरी किले में, मराठा सेनापति शाहजी भोंसले और जीजाबाई के घर हुआ था, जिन्होंने धर्म, बहादुरी और न्याय की अपनी शिक्षाओं से शिवाजी को गहराई से प्रभावित किया था। कम उम्र से ही, शिवाजी ने उल्लेखनीय नेतृत्व गुणों का प्रदर्शन किया, वफादार अनुयायियों का एक समूह बनाया और सह्याद्री पहाड़ों के बीहड़ इलाकों में अपने सैन्य कौशल को बढ़ाया। वह ऐसे समय में बड़ा हुआ जब सम्राट औरंगजेब और दक्कन सल्तनत के अधीन मुगल साम्राज्य नियंत्रण के लिए होड़ कर रहा था, अक्सर स्थानीय आबादी पर अत्याचार करता था, जिसने उसे बहुत परेशान किया और मराठों के लिए स्वराज्य, या स्व-शासन स्थापित करने की उसकी इच्छा को बढ़ावा दिया। 16 साल की उम्र तक, शिवाजी ने गुरिल्ला युद्ध रणनीति का उपयोग करके अपने पहले किले, तोरण पर कब्जा कर लिया था जैसे-जैसे उनकी विजय बढ़ती गई, उन्होंने स्थानीय नेताओं के साथ गठबंधन किया, रायगढ़, कोंडाना और पुरंदर जैसे प्रमुख किलों को सुरक्षित किया, पश्चिमी भारत में एक ठोस क्षेत्रीय आधार स्थापित किया। 1659 में, उन्होंने बीजापुर सल्तनत के एक प्रमुख सेनापति अफ़ज़ल खान का सामना किया और उसे हराया, जिससे एक बहादुर और सामरिक नेता के रूप में उनकी प्रतिष्ठा मजबूत हुई; यह जीत डेक्कन के अधिकांश हिस्से पर अपना नियंत्रण स्थापित करने में महत्वपूर्ण थी। मुगल क्षेत्रों पर शिवाजी के छापे और 1666 में आगरा में औरंगज़ेब के चंगुल से उनके भागने ने उनकी किंवदंती को और मजबूत किया। उन्होंने महसूस किया कि विदेशी आक्रमणों से अपने क्षेत्रों की रक्षा के लिए एक शक्तिशाली नौसेना महत्वपूर्ण थी, जिसके कारण उन्होंने भारत में सबसे शुरुआती संगठित नौसेना बलों में से एक विकसित किया, जिससे उन्हें पुर्तगाली, ब्रिटिश और सिद्दी सेनाओं के खिलाफ तटीय क्षेत्रों को सुरक्षित करने में मदद मिली। 1674 में, उन्होंने औपचारिक रूप से रायगढ़ किले में छत्रपति के रूप में खुद को ताज पहनाया, अपनी स्वतंत्रता की घोषणा की और मराठा साम्राज्य की स्थापना की, इस प्रकार वे हिंदवी स्वराज्य की स्थापना करने वाले पहले राजा बन गए, जो भारतीय लोकाचार में निहित एक संरचित प्रशासनिक ढांचे वाला एक स्वायत्त राज्य था। शिवाजी की प्रशासनिक व्यवस्था अत्यधिक कुशल थी, और उन्होंने अपने लोगों के कल्याण पर जोर दिया, भ्रष्टाचार को कम करने और एक निष्पक्ष कर संरचना बनाने के लिए सिस्टम स्थापित किए; उनके अष्ट प्रधान (आठ मंत्रियों की परिषद) में सुचारू शासन सुनिश्चित करने के लिए वित्त, आंतरिक मामले, विदेश नीति और सैन्य विभाग शामिल थे। शिवाजी ने शासन के प्रति एक प्रगतिशील दृष्टिकोण दिखाया, धार्मिक सहिष्णुता को बढ़ावा दिया और अपने साम्राज्य के भीतर विविधता का सम्मान किया, यहाँ तक कि मुसलमानों को अपने प्रशासन में प्रमुख पदों पर नियुक्त किया और महिलाओं के उत्पीड़न और धार्मिक स्थलों की लूट पर प्रतिबंध लगा दिया। महिलाओं के प्रति उनके सम्मान और न्याय के लिए उनकी वकालत ने उनके लोगों के बीच विश्वास और वफादारी को प्रेरित किया, जिससे वे अपने समय के लिए एक आदर्श शासक बन गए। शिवाजी महाराज की गुरिल्ला रणनीति, जिसे "गनीमी कावा" के रूप में जाना जाता है, प्रसिद्ध हो गई और उन्हें बार-बार बहुत बड़ी और बेहतर सुसज्जित सेनाओं को मात देने में सक्षम बनाया, जिससे उन्हें नुकसान को कम करते हुए अपने साम्राज्य का विस्तार करने में मदद मिली। जैसे-जैसे उनकी प्रसिद्धि बढ़ी, मराठा साम्राज्य ने महाराष्ट्र से परे क्षेत्रों को प्रभावित करना शुरू कर दिया, और मराठा सेना अंततः पूरे भारत में एक महत्वपूर्ण शक्ति बन गई। शिवाजी का निधन 3 अप्रैल, 1680 को रायगढ़ किले में हुआ था, वे अपने पीछे एक शक्तिशाली विरासत और एक सुव्यवस्थित राज्य छोड़ गए थे जो उनकी मृत्यु के बाद भी बढ़ता रहा। उनका जीवन और आदर्श - वीरता, सभी धर्मों के प्रति सम्मान और स्वशासन - लाखों लोगों को प्रेरित करते हैं, और उनकी विरासत भारत के इतिहास और संस्कृति में मराठा साम्राज्य के योगदान के रूप में कायम है।'

# %%
##Translate the phrase "Hindavi Swarajya" into French
text = "Hindavi Swarajya"

translator = GoogleTranslator(source='auto', target='fr')
French_trans = translator.translate(text)
print(French_trans)
# Out:
# Hindavi Swarajya

# %% [markdown]
# #13. Keyword Extraction

# %%
#Extract Keywords using NLTK:

keywords_nltk = [word for word, freq in fdist.items() if freq > 1]
keywords_nltk
# Out:
# ['Chhatrapati',
#  'Shivaji',
#  'was',
#  'on',
#  'at',
#  'in',
#  'Maharashtra,',
#  'to',
#  'a',
#  'Maratha',
#  'and',
#  'deeply',
#  'with',
#  'an',
#  'of',
#  'his',
#  'military',
#  'the',
#  'He',
#  'up',
#  'Mughal',
#  'Empire',
#  'Aurangzeb',
#  'for',
#  'local',
#  'him',
#  'establish',
#  'Swarajya,',
#  'first',
#  'guerrilla',
#  'that',
#  'As',
#  'grew,',
#  'he',
#  'key',
#  'establishing',
#  'India.',
#  'In',
#  'as',
#  'crucial',
#  'much',
#  'Shivaji’s',
#  'territories',
#  'from',
#  'powerful',
#  'foreign',
#  'forces',
#  'allowing',
#  'Raigad',
#  'Fort,',
#  'becoming',
#  'administrative',
#  'people,',
#  'religious',
#  'women',
#  'His',
#  'respect',
#  'expand',
#  'legacy']

# %%
#Identify Unique Keywords using SpaCy:

unique_keywords = set([token.text for token in doc if not token.is_stop and token.is_alpha])
unique_keywords
# Out:
# {'Bhonsle',
#  'Chhatrapati',
#  'February',
#  'Fort',
#  'Jijabai',
#  'Maharaj',
#  'Maharashtra',
#  'Maratha',
#  'Shahaji',
#  'Shivaji',
#  'Shivneri',
#  'born',
#  'bravery',
#  'deeply',
#  'dharma',
#  'general',
#  'influenced',
#  'justice',
#  'teachings'}

# %% [markdown]
# #14. Coreference Resolution

# %%
# !pip install neuralcoref
# Out:
# Collecting neuralcoref
#   Downloading neuralcoref-4.0.tar.gz (368 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 368.7/368.7 kB 12.3 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
#Coreference Resolution:
import spacy
from spacy.tokens import Doc

nlp = spacy.load("en_core_web_sm")
doc = nlp(text)

# %% [markdown]
# #15. Sentiment Polarity Distribution

# %%
#Plot Sentiment Polarity:
import matplotlib.pyplot as plt

polarities = [TextBlob(sentence).sentiment.polarity for sentence in sentences]
plt.hist(polarities)
plt.title('Sentiment Polarity Distribution')
plt.xlabel('Sentiment Polarity')
plt.ylabel('Frequency')
plt.show()

# %%
#Most Positive and Negative Sentences:
most_positive = max(sentences, key=lambda x: TextBlob(x).sentiment.polarity)
most_negative = min(sentences, key=lambda x: TextBlob(x).sentiment.polarity)
print("Most Positive Sentence:", most_positive)
print("Most Negative Sentence:", most_negative)
# Out:
# Most Positive Sentence: His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time.
# Most Negative Sentence: As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India.

# %% [markdown]
# #16. Extract Dates and Events

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp(text)
dates = [ent.text for ent in doc.ents if ent.label_ == "DATE"]
print("Dates Mentioned:", dates)
# Out:
# Dates Mentioned: ['February 19, 1630', 'the age of 16', '1659', '1666', '1674', 'April 3, 1680']

# %%
#Use regex to find sentences related to events happening in specific years (e.g., 1674 or 1680).
import re

pattern = r'\b(?:1674|1680)\b'
matching_sentences = [sentence for sentence in sentences if re.search(pattern, sentence)]
print("Matching Sentences:", matching_sentences)
# Out:
# Matching Sentences: ['In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos.', 'Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death.']

# %% [markdown]
# #17. Synonyms and Antonyms

# %%
#Use TextBlob's WordNet to find synonyms for "bravery," "justice," and "valor."
from textblob import Word
words = ["bravery", "justice", "valor"]

def find_synonyms(word):
    synonyms = set()
    for syn in Word(word).synsets:
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())
    return synonyms

for word in words:
    synonyms = find_synonyms(word)
    print(f"Synonyms for '{word}': {synonyms}")
# Out:
# Synonyms for 'bravery': {'bravery', 'courageousness', 'braveness', 'courage', 'fearlessness'}
# Synonyms for 'justice': {'Justice', 'jurist', 'Department_of_Justice', 'justness', 'judge', 'justice', 'DoJ', 'Justice_Department'}
# Synonyms for 'valor': {'valor', 'gallantry', 'heroism', 'valiance', 'valour', 'valiancy', 'valorousness'}

# %%
#Find antonyms of "oppression" and "invasion" using NLTK’s WordNet.
import nltk
from nltk.corpus import wordnet as wn
nltk.download('wordnet')

def find_antonyms(word):
    antonyms = set()
    for syn in wn.synsets(word):
        for lemma in syn.lemmas():
            if lemma.antonyms():
                antonyms.update(lemma.antonyms())
    return [ant.name() for ant in antonyms]

words = ["oppression", "invasion"]
for word in words:
    antonyms = find_antonyms(word)
    print(f"Antonyms for '{word}':", antonyms)
# Out:
# Antonyms for 'oppression': []
# Antonyms for 'invasion': []
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# #18. Spelling Correction

# %%
#Introduce Errors and Correct:
text_with_errors = "Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings on dharma, bravery, and justice. From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains.."
corrected_text = str(TextBlob(text_with_errors).correct())
print("corrected_text")
corrected_text
# Out:
# corrected_text
# 'Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Sort in Maharashtra, to Shahaji Bhonsle, a Martha general, and Jijabai, who deeply influenced Shivaji with her teachings on harm, bravery, and justice. From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and hoping his military skill in the rugged terrain of the Sahyadri mountains..'

# %% [markdown]
# #19. Extract Subject-Verb-Object Triples

# %%
#Extracting SVO Triples with SpaCy
import spacy

# Load the SpaCy English model
nlp = spacy.load("en_core_web_sm")

doc = nlp(text)
def extract_svo(doc):
    svos = []
    for sent in doc.sents:
        for token in sent:
            if token.dep_ in ("nsubj", "nsubjpass"):
                subject = token.text
                verb = token.head.text
                for child in token.head.children:
                    if child.dep_ in ("dobj"):
                        obj = child.text
                        svos.append((subject, verb, obj))
    return svos

# Extract and print SVO triples
svo_triples = extract_svo(doc)
for subject, verb, obj in svo_triples:
    print(f"Subject: {subject}, Verb: {verb}, Object: {obj}")
# Out:
# Subject: who, Verb: influenced, Object: Shivaji
# Subject: Shivaji, Verb: exhibited, Object: qualities
# Subject: which, Verb: disturbed, Object: him
# Subject: Shivaji, Verb: captured, Object: fort
# Subject: he, Verb: formed, Object: alliances
# Subject: raids, Verb: bolstered, Object: legend
# Subject: him, Verb: secure, Object: areas
# Subject: he, Verb: crowned, Object: himself
# Subject: he, Verb: emphasized, Object: welfare
# Subject: Pradhan, Verb: included, Object: departments
# Subject: Shivaji, Verb: showed, Object: approach
# Subject: respect, Verb: inspired, Object: trust
# Subject: him, Verb: expand, Object: empire

# %%
#Identify and list sentences where "Shivaji" is the subject and a verb follows, using dependency parsing.
shivaji_sentences = []
for sent in doc.sents:
    for token in sent:
        if token.text == "Shivaji" and token.dep_ == "nsubj":
            shivaji_sentences.append(sent.text)
            break

print("Sentences:")
for sentence in shivaji_sentences:
    print(sentence)
# Out:
# Sentences:
# From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains.
# By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy.
# Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites.
# Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death.

# %% [markdown]
# #20- Create a Summary

# %%
#Summarize the text using TextBlob by extracting key sentences.
from textblob import TextBlob

blob = TextBlob(text)
key_sentences = sorted(blob.sentences, key=lambda s: (s.sentiment.polarity, s.sentiment.subjectivity), reverse=True)
summary = ' '.join(str(sentence) for sentence in key_sentences[:5])

# Print the summary
print("TextBlob Summary:")
summary
# Out:
# TextBlob Summary:
# 'His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time. Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legendary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses. In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos. In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan. As his fame grew, the Maratha Empire began to influence regions far beyond Maharashtra, with Maratha forces eventually becoming a significant power across India.'

# %%
from nltk.tokenize import sent_tokenize
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lsa import LsaSummarizer

# Summarizing using Sumy
parser = PlaintextParser.from_string(text, Tokenizer("english"))
summarizer = LsaSummarizer()
sumy_summary = summarizer(parser.document, 3)

print("\nSumy Summary:")
for sentence in sumy_summary:
    print(sentence)
# Out:
# Sumy Summary:
# As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India.
# In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan.
# In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos.
